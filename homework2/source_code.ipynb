# %%
# SCIPER = 377212
# id = 377212
# seed = 1713990049382644373
# Worked with (list all): 374999

# %% [markdown]
# ## Exercise 1

# %%
###### Exercise 1
Q1_param=[-35, 98]
Q1_p=434252269029337012720086440207
Q1_P=[16378704336066569231287640165, 377857010369614774097663166640, 1]
Q1_Q=[170183259892403233339249657941, 263615296934133211737499882304, 1]

# %% [markdown]
# ## Part 1

# %%
# Define the elliptic curve E
K = GF(Q1_p)
E = EllipticCurve(K, Q1_param)

# Define the points on the elliptic curve
Q1_P = E.point(Q1_P)
Q1_Q = E.point(Q1_Q)

# %%
def compute_embedding_degree(Q1_p, M):
    k = 1
    while power_mod(Q1_p, k, M) != 1:
        k += 1
    return k

M = E.order()
k = compute_embedding_degree(Q1_p, M)
assert power_mod(Q1_p, k, M) == 1
print("k = ", k)
# Out:
# k =  2

# %% [markdown]
# ## Part 2

# %%
# Define the elliptic curve E
K.<y> = GF((Q1_p,2))
E = EllipticCurve(K, Q1_param)

# Define the points on the elliptic curve
Q1_P = E.point(Q1_P)
Q1_Q = E.point(Q1_Q)

Q1b_S1=E.point([16378704336066569231287640165, 377857010369614774097663166640, 1])
Q1b_S2=E.point([89992094488343326997563884035*y + 431845742011406135690517831582, 208703093282631048368815107018*y + 210291335136919640212691183502, 1])

# %%
Q1b_S1.weil_pairing(Q1b_S2, Q1b_S1.order())
# Out:
# 227772935092204082036291893023*y + 189439879840574597421063947448

# %%
R = E.random_point()

while Q1_P.weil_pairing(R, Q1_P.order()) == 1:
    R = E.random_point()
print(R)

a = Q1_Q.weil_pairing(R, Q1_P.order())
b = Q1_P.weil_pairing(R, Q1_P.order())

n = a.log(b)
assert Q1_Q == n * Q1_P

print(f"n = {n}")
# Out:
# (176126743501225939327138524387*y + 235593788794225203122178421836 : 377835790030588297431402871686*y + 252734668489839948670011629788 : 1)
# n = 10091252348221843969

# %% [markdown]
# # Exercise 2

# %%
###### Exercise 2
Q2a_pk=38940212774339704661192536161647171048881840277149443858886686126128036691253
Q2a_p=82206896951094810306638522581533370887738060210540137506559775739470561485893
Q2a_g=61644338045702977544039466855221928750494939843628702097227764067763715696157
Q2a_N=13
Q2a_C=[(20919810630646668383875571087240319252213787310513947562946106917291413097171, 18522400337458861681269374779283404761135244649962608102280855856248432854602), (79776121044558900285771282792741568360191180998458686744826595849290252323804, 57253998165483701458722135583367987198747111109353208303587472014649168746753), (76302694376132108817251345521420815067000897286181242398592714338733743188954, 24205228310419720791434594035664561234729202000249556069071802787714128803789), (75951260062431043324176993385523983340531710020527186473664393815203425197004, 36640477498030028925490458208216791645541297277542461029559469213702221379089), (49538142742543559594575932810918607009287406857366872946956579929020620919074, 81841666985189340658809070615933938443239616183499213763588409482494036784859), (11136142015494230506767215458716693944822572585339760181772060480550221324762, 40272632873476923258511175435939731942327616490081368466179582948370473055519), (1133579784275533389037439597948037371567924707575904992147528989804588796250, 12877461280578448352128480568251322008317453727442547124799174699721452892779), (2758259767560682267353906986731598308422681901407497708461571371990855576627, 52219470710286183638636714542569034908327550959416148937122306569241745934834), (21328318367866874062727634157587708971493676511482729514220572542153127527456, 15584313830767381505883534141803297568964123267048774601143608141313812926886), (17272391007946448013287401102481515860820478636946991443951022832651071332325, 13488107544380026270160844727953137804498002768934040945539746016736433728662), (81068495077019560652202641904175845401341243675783602568924886958579833476282, 16276469765051752246634577283468583434111321763572310070110617106310013653526), (16623872591283264956123706735676157630399907864213701352642689526329628113865, 59592313388240346925011160631704480621442330737270111572761923263907887735497), (73291247664330077517970974665807768395711878692461152522227810324702952876916, 14255562317277044810763846111002200016132991181870122996436075823333737304427)]

# %% [markdown]
# ## Exercise 2 solution

# %%
## Exercise 2

F = Zmod(Q2a_p)
g = F(Q2a_g)
ord_g = g.multiplicative_order()

# Finding the value \sum_{i=1}^{13} r_i

g_pow_sumr = F(1)
for u in Q2a_C:
    g_pow_sumr = g_pow_sumr * u[0]

sumr = discrete_log(g_pow_sumr, Q2a_g, F.order())

# The following commented lines show 
# the correctness of the value sumr just computed through discrete_log function:

# print("The sum of all the ratings modulo Q2a_p - 1 = ", sumr) # outputs 116
# print(f"g^116 == g_pow_sumr ?\t{g^116 == g_pow_sumr}")

prod_v = F(1)
for v in Q2a_C:
    prod_v = prod_v * v[1]

prod_r = prod_v * power_mod(Q2a_pk, -sumr, Q2a_p)

Q2a_rmult = prod_r

print("Q2a_rmult = ",Q2a_rmult)
# Out:
# Q2a_rmult =  61142471332249865937774386582603665034947823238192258506903558211200896642727

# %% [markdown]
# ## Test Exercise 2 solution
# We do this by solving the exercise with self-made ("random") ratings

# %%
import random

# rand_ratings = [F(random.randrange(Q2a_p)) for i in range(Q2a_N - 2)] + [F(Q2a_p)] + [F(ord_g)]
rand_ratings = [F(1) for i in range(Q2a_N - 2)] + [F(Q2a_p - 3849)] + [F(24242)]


# Manual SUM

actual_rand_sum = F(0)
for r in rand_ratings:
    actual_rand_sum += r
    
print("Print manual sum of ratings")
# print(type(actual_rand_sum))
print("raw is ", actual_rand_sum)
print("mod p is ", F(actual_rand_sum))
print()


# Manual PRODUCT

actual_rand_prod = F(1)
for r in rand_ratings:
    actual_rand_prod = r * actual_rand_prod

print("Print manual product of ratings")
# print(type(actual_rand_prod))
print("raw is ", actual_rand_prod)
print("mod p is ", F(actual_rand_prod))
print()


# Create Us and Vs

rand_Us = [power_mod(Q2a_g, rat, Q2a_p) for rat in rand_ratings]
rand_Vs = [power_mod(Q2a_pk, rat, Q2a_p) * rat for rat in rand_ratings]

# print("Print about randum Us and Vs")
# print("type Us ", type(rand_Us[0]))
# print("type Vs ", type(rand_Vs[0]))
# print()


def solve(Us, Vs, pk, p, g):
    
    F = Zmod(p)
    g = F(g)
    
    prodU = F(1)
    for u in Us:
        prodU = prodU * u
        
    prodV = F(1)
    for v in Vs:
        prodV = prodV * v
        
    sumR = discrete_log(prodU, g, F.order())
    print("discrete log to get sum from exponent, sum is ", sumR) 
    assert g^sumR == prodU
    
    prodU_inverse = power_mod(pk, -sumR, p)
    prodR = prodV * prodU_inverse
    
    return prodR


test_prodR = solve(rand_Us, rand_Vs, Q2a_pk, Q2a_p, Q2a_g)

print("Q2a_rmult = ", test_prodR )

assert test_prodR == actual_rand_prod

print("\nNo AssertionError raised!")
# Out:
# Print manual sum of ratings
# raw is  20404
# mod p is  20404
#
# Print manual product of ratings
# raw is  82206896951094810306638522581533370887738060210540137506559775739470468178435
# mod p is  82206896951094810306638522581533370887738060210540137506559775739470468178435
#
# discrete log to get sum from exponent, sum is  20405
# Q2a_rmult =  82206896951094810306638522581533370887738060210540137506559775739470468178435
#
# No AssertionError raised!

# %% [markdown]
# # Exercise 3

# %%
###### Exercise 3
Q3a_N=
Q3a_L=[, , , ]
Q3a_y=
Q3b_N=...
Q3b_PKS=[..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...]
Q3b_PAIRS=[(..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...), (..., ...)]
Q3b_CT_RSA=10960180517047634559954793955056877223966906833394047588203554464813643001620139583969326588340514520488899125000
Q3b_CT_AES=b'\xf0\xd3\xcf\x07G\xe9\x00\x88\xd1#\xdd\xa9\x15MP\\(N\x0f`I\xc2\xb4\xbd\x83\x9bSx_\x0c\xf66\xabT\x89\x18$8#\x91\xba\xedr.Tk\x0b2\x13\xc50\xfd\x01\xf9\xc6\xe4\x98\x1b\xcb\xd3\x86\x96\x9c\x1f+\x13\xe4f\x19?\xed\x98\xea\x0e\xf1=\x1al\xb0\x89V\r\xdbO\x1fYO\x89m\xc1\xa8\xf4\xfd\xe5\xe5\x8d\x13pw'
Q3b_CT_NONCE=b'\x89\xd9\x06Tb\xae4\xc2\xf8*4\xefg\xd9~\x15'
Q3b_CT_TAG=b'\xd6lg\xe6=\x1a\xedBxD\xb9\x8ahb}\xa4'

# %% [markdown]
# ## Part 1

# %%
# get last element of the list of points

last_elem_bits = Q3a_L[-1].bits()

# brute force last 15 bits until we find a nontrivial root of 1

bitlen = len(last_elem_bits)
nontrivial_root = 0

for n in range(0, 2**15):
    
    bits = Integer(n).bits()
    
    L = len(bits)
    padded_bits = bits + ([0] * (15 - L))
    
    attempt = padded_bits + last_elem_bits[15:] 
    assert len(attempt) == bitlen
    int_val = ZZ(attempt, base=2)
    square = power_mod(int_val, 2, Q3a_N)
    if square == 1:
        nontrivial_root = int_val
        break
        

    
print("Nontrivial root of 1 is ", nontrivial_root)
print("Root squared mod N is ", power_mod(nontrivial_root, 2, Q3a_N))

# find GCD of N and the nontrivial root minus 1

nontrivial_factor = GCD(Q3a_N, nontrivial_root - 1)
P = nontrivial_factor
Q = ZZ(Q3a_N / P)

print("First nontrivial factor of N is\nP = ", P)
print("Is P prime?  ", P.is_prime())
print("Second nontrivial factor of N is\nQ = ", Q)
print("Is Q prime?  ", Q.is_prime())

print("Do the two nontrivial factors found multiply to N?  ", P*Q == Q3a_N)

print()
print("Finding QRs mod P and Q...")

Zn = Zmod(Q3a_N)
Zp = Zmod(P)
Zq = Zmod(Q)

QR_modP = power_mod(Q3a_y, (P+1)/4, P) # square_root_mod_prime(Q3a_y, p=P)
other = sqrt(Zp(Q3a_y))

assert power_mod(QR_modP, 2, P) == (Q3a_y % P)
assert other == QR_modP

QR_modQ = sqrt(Zq(Q3a_y))

assert power_mod(QR_modP, 2, P) == (Q3a_y % P)
assert power_mod(QR_modQ, 2, Q) == (Q3a_y % Q)

print("QR of y mod P is ", QR_modP)
print("QR of y mod Q is ", QR_modQ)

print()
print("Combining QRs of Y with CRT...")
print()

root00 = crt(ZZ(QR_modP), ZZ(QR_modQ), P, Q)
root01 = crt(ZZ(QR_modP), ZZ(Zq(Q - QR_modQ)), P, Q)
root10 = crt(ZZ(Zp(P - QR_modP)), ZZ(Zq(QR_modQ)), P, Q)
root11 = crt(ZZ(Zp(P - QR_modP)), ZZ(Zq(Q - QR_modQ)), P, Q)

rootsY = sorted([root00, root01, root10, root11])

# make sure no roots are duplicates
assert(len(set(rootsY)) == 4)

assert power_mod(root01, 2, Q3a_N) == Zn(Q3a_y)
assert power_mod(root10, 2, Q3a_N) == Zn(Q3a_y)
assert power_mod(root10, 2, Q3a_N) == Zn(Q3a_y)
assert power_mod(root11, 2, Q3a_N) == Zn(Q3a_y)

# for i in range(4):
#     print(f"Root number {i} of Y is:")
#     print(rootsY[i])
#     print()
    
print("Roots in ascending order are:\nQ3a_x = ", rootsY)
# Out:
# Nontrivial root of 1 is  
# Root squared mod N is  1
# First nontrivial factor of N is
# P =  8014165691280375215446880416632063357734950023723809826873816903996870325467663175122386959791859398478443760158474364191711410852494165061296598613054643
# Is P prime?   True
# Second nontrivial factor of N is
# Q =  10843070529237274745105613133465526390361217477997683423966831625014315882745935000940595207031219423603268857569961473689921997522116972761130500021191001
# Is Q prime?   True
# Do the two nontrivial factors found multiply to N?   True
#
# Finding QRs mod P and Q...
# ...

# %% [markdown]
# ## Part 2

# %%
p = 0
for i in range(len(Q3b_PKS)):
    if gcd(Q3b_PKS[i], Q3b_N) != 1:
        p = gcd(Q3b_PKS[i], Q3b_N)

print("The first factor that has been found for Q3b_N is\np = ",p)
print("Is p prime?\t", p.is_prime())
qr = Q3b_N / p
print("\nBy computing qr = Q3b_N / p, we have that another non trivial factor of Q3b_N is\nqr = ", qr)
print("Is qr prime?\t", qr.is_prime())
print("\nHence, it must be the case that\nQ3b_N = p * q * r\n")

glitch_X, glitch_Y = 0, 0

for i, j in Q3b_PAIRS:
    if i != j:
        glitch_X = i 
        glitch_Y = j 

Z_N = Zmod(Q3b_N)

Z_QR = Zmod(qr)
Z_P = Zmod(p)

random_mod_p = Z_P(glitch_Y)
X_mod_p = Z_P(glitch_X)
print("Did the glitch occur while decrypting mod p ?\t", random_mod_p != X_mod_p)

random_mod_qr = Z_QR(glitch_Y)
X_mod_qr = Z_QR(glitch_X)
print("Did the glitch occur while decrypting mod qr ?\t", random_mod_qr != X_mod_qr)

# Computing the second factor of Q3b_N
print("\nComputing r and q...")
r = GCD(Q3b_N / p, glitch_Y - glitch_X)
print("r = ",r)
q = Q3b_N / r / p
print("q = ", q)
print('Is r prime ?\t', Integer(r).is_prime())
q = Q3b_N / r / p
print('Is q prime ?\t', Integer(q).is_prime())

print(f"r * q * p == Q3b_N ?\t{r * q * p == Q3b_N}")

# Computing the private key d
print("\nComputing the private key d...")

from sage.arith.misc import XGCD

Z_phi = Zmod((p - 1)*(q - 1)*(r - 1))
d = Z_phi(XGCD(3, (p - 1)*(q - 1)*(r - 1))[1])
print("d = ", d)

# Checking that the computed private key d is valid
print(f"Is d a valid private key?\t{Z_phi(d*3) == 1}")

rec_k_aes = power_mod(Q3b_CT_RSA, d, Q3b_N)
# print(Z_N(power_mod(Q3b_CT_RSA, d, Q3b_N)))
print("\nrec_k_aes =", rec_k_aes)
# Out:
# The first factor that has been found for Q3b_N is
# p =  11484498371835078457807241035043762004292267886098395186989553975931730973448103109449379222975876950535905876138849003806619617789221342324224416840961273
# Is p prime?	 True
#
# By computing qr = Q3b_N / p, we have that another non trivial factor of Q3b_N is
# qr =  
# Is qr prime?	 False
#
# Hence, it must be the case that
# Q3b_N = p * q * r
#
# Did the glitch occur while decrypting mod p ?	 False
# Did the glitch occur while decrypting mod qr ?	 True
#
# Computing r and q...
# ...

# %% [markdown]
# The **decryption** is performed in a seperate python script file named *'377212-sol_ex3.2.py'*
